# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
# Desactivo warning molesto
pd.options.mode.chained_assignment = None  # default='warn'

# %%
eventos = pd.read_csv('/home/lautaro/Desktop/events_up_to_01062018.csv', low_memory=False)

# %%
labels_junio = pd.read_csv('/home/lautaro/Desktop/labels_training_set.csv')

# %%
eventos.head()
# Out:
#              timestamp           event    person  url      sku  \
# 0  2018-05-18 00:11:59  viewed product  4886f805  NaN   9288.0
# 1  2018-05-18 00:11:27  viewed product  ad93850f  NaN    304.0
# 2  2018-05-18 00:11:16  viewed product  0297fc1e  NaN   6888.0
# 3  2018-05-18 00:11:14  viewed product  2d681dd8  NaN  11890.0
# 4  2018-05-18 00:11:09  viewed product  cccea85e  NaN   7517.0
#
#                      model  condition storage           color skus  \
# 0  Samsung Galaxy J7 Prime  Excelente    32GB         Dourado  NaN
# 1                iPhone 5s  Muito Bom    32GB  Cinza espacial  NaN
# 2                iPhone 6S  Muito Bom    64GB        Prateado  NaN
# 3                 iPhone 7        Bom   128GB        Vermelho  NaN
# 4              LG G4 H818P  Excelente    32GB          Branco  NaN
#
#         ...       search_engine channel new_vs_returning city region country  \
# 0       ...                 NaN     NaN              NaN  NaN    NaN     NaN
# 1       ...                 NaN     NaN              NaN  NaN    NaN     NaN
# 2       ...                 NaN     NaN              NaN  NaN    NaN     NaN
# 3       ...                 NaN     NaN              NaN  NaN    NaN     NaN
# 4       ...                 NaN     NaN              NaN  NaN    NaN     NaN
#
#   device_type screen_resolution operating_system_version browser_version
# 0         NaN               NaN                      NaN             NaN
# 1         NaN               NaN                      NaN             NaN
# 2         NaN               NaN                      NaN             NaN
# 3         NaN               NaN                      NaN             NaN
# 4         NaN               NaN                      NaN             NaN
#
# [5 rows x 23 columns]

# %%
labels_junio.head()
# Out:
#      person  label
# 0  0566e9c1      0
# 1  6ec7ee77      0
# 2  abe7a2fb      0
# 3  34728364      0
# 4  87ed62de      0

# %%
eventos["timestamp"] = pd.to_datetime(eventos["timestamp"])

# %% [markdown]
# El csv de labels tiene las personas y un booleano indicando si compraron. Por lo tanto mi objetivo es transformar el csv de eventos en uno que tenga información para cada persona.

# %%
# Como estoy evaluando a los usuarios no me interesa los eventos que no tengan una persona asociada
eventos.loc[eventos['person'].isnull() == True,:]
# Out:
# Empty DataFrame
# Columns: [timestamp, event, person, url, sku, model, condition, storage, color, skus, search_term, staticpage, campaign_source, search_engine, channel, new_vs_returning, city, region, country, device_type, screen_resolution, operating_system_version, browser_version]
# Index: []
#
# [0 rows x 23 columns]

# %%
eventos["busquedas_exactas"] = (eventos["search_term"].notnull() & eventos["search_term"].isin(eventos['model'].unique()))

# %%
eventos["terminos_buscados"] = eventos['search_term'].replace(np.nan, '', regex=True).str.split().apply(len)

# %%
eventos['marca'] = eventos['model'].str.split(' ', n = 1, expand = True)[0]

# %%
eventos['Samsung'] = (eventos['marca'] == 'Samsung')
eventos['iPhone'] = (eventos['marca'] == 'iPhone')
eventos['LG'] = (eventos['marca'] == 'LG')
eventos['Motorola'] = (eventos['marca'] == 'Motorola')
eventos['iPad'] = (eventos['marca'] == 'iPad')
eventos['Sony'] = (eventos['marca'] == 'Sony')
eventos['Lenovo'] = (eventos['marca'] == 'Lenovo')
eventos['Quantum'] = (eventos['marca'] == 'Quantum')
eventos['Asus'] = (eventos['marca'] == 'Asus')
eventos['Xiaomi'] = (eventos['marca'] == 'Xiaomi')
eventos['Outros'] = (eventos['marca'] == 'Outros')

# %%
eventos['Bom'] = (eventos['condition'] == 'Bom')
eventos['Muito_Bom'] = (eventos['condition'] == 'Muito Bom')
eventos['Excelente'] = (eventos['condition'] == 'Excelente')

# %% [markdown]
# Se me ocurre que podría extraer la columa "event" y hacer una columna por cada evento con un booleano, esto me ayudaria a contar la cantidad de veces que se registraron los eventos para cada usuario.

# %%
eventos['viewed_product'] = (eventos['event'] == 'viewed product')
eventos['brand_listing'] = (eventos['event'] == 'brand listing')
eventos['visited_site'] = (eventos['event'] == 'visited site')
eventos['ad_campaign_hit'] = (eventos['event'] == 'ad campaign hit')
eventos['generic_listing'] = (eventos['event'] == 'generic listing')
eventos['searched_products'] = (eventos['event'] == 'searched products')
eventos['search_engine_hit'] = (eventos['event'] == 'search engine hit')
eventos['checkout'] = (eventos['event'] == 'checkout')
eventos['staticpage'] = (eventos['event'] == 'staticpage')
eventos['conversion'] = (eventos['event'] == 'conversion')
eventos['lead'] = (eventos['event'] == 'lead')
eventos['total_eventos'] = 1;

# %%
eventos.head()
# Out:
#             timestamp           event    person  url      sku  \
# 0 2018-05-18 00:11:59  viewed product  4886f805  NaN   9288.0
# 1 2018-05-18 00:11:27  viewed product  ad93850f  NaN    304.0
# 2 2018-05-18 00:11:16  viewed product  0297fc1e  NaN   6888.0
# 3 2018-05-18 00:11:14  viewed product  2d681dd8  NaN  11890.0
# 4 2018-05-18 00:11:09  viewed product  cccea85e  NaN   7517.0
#
#                      model  condition storage           color skus  \
# 0  Samsung Galaxy J7 Prime  Excelente    32GB         Dourado  NaN
# 1                iPhone 5s  Muito Bom    32GB  Cinza espacial  NaN
# 2                iPhone 6S  Muito Bom    64GB        Prateado  NaN
# 3                 iPhone 7        Bom   128GB        Vermelho  NaN
# 4              LG G4 H818P  Excelente    32GB          Branco  NaN
#
#        ...      brand_listing  visited_site ad_campaign_hit generic_listing  \
# 0      ...              False         False           False           False
# 1      ...              False         False           False           False
# 2      ...              False         False           False           False
# 3      ...              False         False           False           False
# 4      ...              False         False           False           False
#
#   searched_products search_engine_hit checkout conversion   lead total_eventos
# 0             False             False    False      False  False             1
# 1             False             False    False      False  False             1
# 2             False             False    False      False  False             1
# 3             False             False    False      False  False             1
# 4             False             False    False      False  False             1
#
# [5 rows x 51 columns]

# %% [markdown]
# La columna "timestamp" me parece muy importante pero como voy a tener que agrupar todos los eventos de una persona a una sola fila necesito hacer algo con ella. Se me ocurre que puedo agregar columnas para determinar si cada evento tuvo lugar por ejemplo una columa por mes. Esta creación de columnas va a estar muy ligada al hecho que los datos que tenemos van desde principio de este año hasta junio.

# %%
eventos["mes"] = eventos["timestamp"].dt.month
eventos["dia_del_anio"] = eventos["timestamp"].dt.dayofyear
eventos["semana"] = eventos["timestamp"].dt.week
eventos["dia"] = eventos["timestamp"].dt.day

# %%
# Obtengo la ultima fecha disponible en el csv para tener un punto de partida
ultima_fecha = eventos["timestamp"].max()
ultimo_dia = ultima_fecha.dayofyear
ultimo_mes = ultima_fecha.month
ultima_semana = ultima_fecha.week

# %%
# Agrego columna para obtener los dias desde el evento
eventos["dias_ultimo_evento"] = (ultimo_dia - eventos["dia_del_anio"])

# %%
# Agrego columna para saber hace cuanto compro en la pagina
eventos["dias_ultima_compra"] = ultimo_dia
eventos.loc[eventos["conversion"] == True, "dias_ultima_compra"] = ultimo_dia - eventos["dia_del_anio"]

# %%
# Agrego columnas para los m meses más cercanos
for m in range (0, ultimo_mes):
    eventos["mes_pasado_" + str(m)] = (eventos["mes"] == (ultimo_mes - m))
    eventos['viewed_product_mes_pasado_' + str(m)] = ((eventos['event'] == 'viewed product') & (eventos["mes_pasado_" + str(m)] == True))
    eventos['brand_listing_mes_pasado_' + str(m)] = ((eventos['event'] == 'brand listing') & (eventos["mes_pasado_" + str(m)] == True))
    eventos['visited_site_mes_pasado_' + str(m)] = ((eventos['event'] == 'visited site') & (eventos["mes_pasado_" + str(m)] == True))
    eventos['ad_campaign_hit_mes_pasado_' + str(m)] = ((eventos['event'] == 'ad campaign hit') & (eventos["mes_pasado_" + str(m)] == True))
    eventos['generic_listing_mes_pasado_' + str(m)] = ((eventos['event'] == 'generic listing') & (eventos["mes_pasado_" + str(m)] == True))
    eventos['searched_products_mes_pasado_' + str(m)] = ((eventos['event'] == 'searched products') & (eventos["mes_pasado_" + str(m)] == True))
    eventos['search_engine_hit_mes_pasado_' + str(m)] = ((eventos['event'] == 'search engine hit') & (eventos["mes_pasado_" + str(m)] == True))
    eventos['checkout_mes_pasado_' + str(m)] = ((eventos['event'] == 'checkout') & (eventos["mes_pasado_" + str(m)] == True))
    eventos['staticpage_mes_pasado_' + str(m)] = ((eventos['event'] == 'staticpage') & (eventos["mes_pasado_" + str(m)] == True))
    eventos['conversion_mes_pasado_' + str(m)] = ((eventos['event'] == 'conversion') & (eventos["mes_pasado_" + str(m)] == True))
    eventos['lead_mes_pasado_' + str(m)] = ((eventos['event'] == 'lead') & (eventos["mes_pasado_" + str(m)] == True))
    eventos['Bom_mes_pasado_' + str(m)] = ((eventos['Bom'] == True) & (eventos["mes_pasado_" + str(m)] == True))
    eventos['Muito_Bom_mes_pasado_' + str(m)] = ((eventos['Muito_Bom'] == True) & (eventos["mes_pasado_" + str(m)] == True))
    eventos['Excelente_mes_pasado_' + str(m)] = ((eventos['Excelente'] == True) & (eventos["mes_pasado_" + str(m)] == True))
    eventos['Samsung_mes_pasado_' + str(m)] = ((eventos['Samsung'] == True) & (eventos["mes_pasado_" + str(m)] == True))
    eventos['iPhone_mes_pasado_' + str(m)] = ((eventos['iPhone'] == True) & (eventos["mes_pasado_" + str(m)] == True))
    eventos['LG_mes_pasado_' + str(m)] = ((eventos['LG'] == True) & (eventos["mes_pasado_" + str(m)] == True))
    eventos['Motorola_mes_pasado_' + str(m)] = ((eventos['Motorola'] == True) & (eventos["mes_pasado_" + str(m)] == True))
    eventos['iPad_mes_pasado_' + str(m)] = ((eventos['iPad'] == True) & (eventos["mes_pasado_" + str(m)] == True))
    eventos['Sony_mes_pasado_' + str(m)] = ((eventos['Sony'] == True) & (eventos["mes_pasado_" + str(m)] == True))
    eventos['Lenovo_mes_pasado_' + str(m)] = ((eventos['Lenovo'] == True) & (eventos["mes_pasado_" + str(m)] == True))
    eventos['Quantum_mes_pasado_' + str(m)] = ((eventos['Quantum'] == True) & (eventos["mes_pasado_" + str(m)] == True))
    eventos['Asus_mes_pasado_' + str(m)] = ((eventos['Asus'] == True) & (eventos["mes_pasado_" + str(m)] == True))
    eventos['Xiaomi_mes_pasado_' + str(m)] = ((eventos['Xiaomi'] == True) & (eventos["mes_pasado_" + str(m)] == True))
    eventos['Outros_mes_pasado_' + str(m)] = ((eventos['Outros'] == True) & (eventos["mes_pasado_" + str(m)] == True))
    eventos['busquedas_exactas_mes_pasado_' + str(m)] = ((eventos['busquedas_exactas'] == True) & (eventos["mes_pasado_" + str(m)] == True))

# %%
eventos.head()
# Out:
#             timestamp           event    person  url      sku  \
# 0 2018-05-18 00:11:59  viewed product  4886f805  NaN   9288.0
# 1 2018-05-18 00:11:27  viewed product  ad93850f  NaN    304.0
# 2 2018-05-18 00:11:16  viewed product  0297fc1e  NaN   6888.0
# 3 2018-05-18 00:11:14  viewed product  2d681dd8  NaN  11890.0
# 4 2018-05-18 00:11:09  viewed product  cccea85e  NaN   7517.0
#
#                      model  condition storage           color skus  \
# 0  Samsung Galaxy J7 Prime  Excelente    32GB         Dourado  NaN
# 1                iPhone 5s  Muito Bom    32GB  Cinza espacial  NaN
# 2                iPhone 6S  Muito Bom    64GB        Prateado  NaN
# 3                 iPhone 7        Bom   128GB        Vermelho  NaN
# 4              LG G4 H818P  Excelente    32GB          Branco  NaN
#
#                ...               LG_mes_pasado_4  Motorola_mes_pasado_4  \
# 0              ...                         False                  False
# 1              ...                         False                  False
# 2              ...                         False                  False
# 3              ...                         False                  False
# 4              ...                         False                  False
#
#   iPad_mes_pasado_4 Sony_mes_pasado_4 Lenovo_mes_pasado_4  \
# 0             False             False               False
# 1             False             False               False
# 2             False             False               False
# 3             False             False               False
# 4             False             False               False
#
#   Quantum_mes_pasado_4 Asus_mes_pasado_4 Xiaomi_mes_pasado_4  \
# 0                False             False               False
# 1                False             False               False
# 2                False             False               False
# 3                False             False               False
# 4                False             False               False
#
#   Outros_mes_pasado_4 busquedas_exactas_mes_pasado_4
# 0               False                          False
# 1               False                          False
# 2               False                          False
# 3               False                          False
# 4               False                          False
#
# [5 rows x 192 columns]

# %%
# Agrego columnas para las s semanas más cercanas
for s in range (0, 17):
    eventos["semana_pasada_" + str(s)] = (eventos["semana"] == (ultima_semana - s))

# %%
eventos.head()
# Out:
#             timestamp           event    person  url      sku  \
# 0 2018-05-18 00:11:59  viewed product  4886f805  NaN   9288.0
# 1 2018-05-18 00:11:27  viewed product  ad93850f  NaN    304.0
# 2 2018-05-18 00:11:16  viewed product  0297fc1e  NaN   6888.0
# 3 2018-05-18 00:11:14  viewed product  2d681dd8  NaN  11890.0
# 4 2018-05-18 00:11:09  viewed product  cccea85e  NaN   7517.0
#
#                      model  condition storage           color skus  \
# 0  Samsung Galaxy J7 Prime  Excelente    32GB         Dourado  NaN
# 1                iPhone 5s  Muito Bom    32GB  Cinza espacial  NaN
# 2                iPhone 6S  Muito Bom    64GB        Prateado  NaN
# 3                 iPhone 7        Bom   128GB        Vermelho  NaN
# 4              LG G4 H818P  Excelente    32GB          Branco  NaN
#
#         ...        semana_pasada_7  semana_pasada_8 semana_pasada_9  \
# 0       ...                  False            False           False
# 1       ...                  False            False           False
# 2       ...                  False            False           False
# 3       ...                  False            False           False
# 4       ...                  False            False           False
#
#   semana_pasada_10 semana_pasada_11 semana_pasada_12 semana_pasada_13  \
# 0            False            False            False            False
# 1            False            False            False            False
# 2            False            False            False            False
# 3            False            False            False            False
# 4            False            False            False            False
#
#   semana_pasada_14 semana_pasada_15 semana_pasada_16
# 0            False            False            False
# 1            False            False            False
# 2            False            False            False
# 3            False            False            False
# 4            False            False            False
#
# [5 rows x 209 columns]

# %% [markdown]
# eventos = eventos.loc[:,['person', 'viewed_product', 'brand_listing', 'visited_site',
#        'ad_campaign_hit', 'generic_listing', 'searched_products',
#        'search_engine_hit', 'checkout', 'conversion', 'lead',
# 'mes_pasado_0', 'mes_pasado_1', 'mes_pasado_2', 'mes_pasado_3',
#      'semana_pasada_0', 'semana_pasada_1', 'semana_pasada_2',
#      'semana_pasada_3', 'semana_pasada_4']]

# %%
eventos.columns
# Out:
# Index([u'timestamp', u'event', u'person', u'url', u'sku', u'model',
#        u'condition', u'storage', u'color', u'skus',
#        ...
#        u'semana_pasada_7', u'semana_pasada_8', u'semana_pasada_9',
#        u'semana_pasada_10', u'semana_pasada_11', u'semana_pasada_12',
#        u'semana_pasada_13', u'semana_pasada_14', u'semana_pasada_15',
#        u'semana_pasada_16'],
#       dtype='object', length=209)

# %%
usuarios_junio = eventos.groupby('person', as_index=False).agg({
                                         'conversion' : 'sum',
                                         'viewed_product_mes_pasado_0':'sum', 
                                         'brand_listing_mes_pasado_0':'sum',
                                         'visited_site_mes_pasado_0':'sum', 
                                         'ad_campaign_hit_mes_pasado_0': 'sum',
                                         'generic_listing_mes_pasado_0' : 'sum',
                                         'searched_products_mes_pasado_0' : 'sum',
                                         'search_engine_hit_mes_pasado_0' : 'sum',
                                         'checkout_mes_pasado_0' : 'sum',
                                         'conversion_mes_pasado_0' : 'sum',
                                         'mes_pasado_0' : 'sum',
                                         'mes_pasado_1' : 'sum',
                                         'semana_pasada_0' : 'sum',
                                         'semana_pasada_1' : 'sum',
                                         'semana_pasada_2' : 'sum',
                                         'semana_pasada_3' : 'sum',
                                         'semana_pasada_4' : 'sum',
                                         'dias_ultimo_evento' : 'min',
                                         'dias_ultima_compra' : 'min',
                                         'Bom_mes_pasado_0' : 'sum',
                                         'Muito_Bom_mes_pasado_0' : 'sum',
                                         'Excelente_mes_pasado_0' : 'sum',
                                         'Samsung_mes_pasado_0' : 'sum',
                                         'iPhone_mes_pasado_0' : 'sum'})

# %%
usuarios_mayo = eventos.loc[eventos["mes"] < 5,:].groupby('person', as_index=False).agg({
                                         'conversion' : 'sum',
                                         'viewed_product_mes_pasado_1':'sum', 
                                         'brand_listing_mes_pasado_1':'sum',
                                         'visited_site_mes_pasado_1':'sum', 
                                         'ad_campaign_hit_mes_pasado_1': 'sum',
                                         'generic_listing_mes_pasado_1' : 'sum',
                                         'searched_products_mes_pasado_1' : 'sum',
                                         'search_engine_hit_mes_pasado_1' : 'sum',
                                         'checkout_mes_pasado_1' : 'sum',
                                         'conversion_mes_pasado_1' : 'sum',
                                         'mes_pasado_1' : 'sum',
                                         'mes_pasado_2' : 'sum',
                                         'semana_pasada_4' : 'sum',
                                         'semana_pasada_5' : 'sum',
                                         'semana_pasada_6' : 'sum',
                                         'semana_pasada_7' : 'sum',
                                         'semana_pasada_8' : 'sum',
                                         'dias_ultimo_evento' : 'min',
                                         'dias_ultima_compra' : 'min',
                                         'Bom_mes_pasado_1' : 'sum',
                                         'Muito_Bom_mes_pasado_1' : 'sum',
                                         'Excelente_mes_pasado_1' : 'sum',
                                         'Samsung_mes_pasado_1' : 'sum',
                                         'iPhone_mes_pasado_1' : 'sum'})

# %%
usuarios_abril = eventos.loc[eventos["mes"] < 4,:].groupby('person', as_index=False).agg({
                                         'conversion' : 'sum',
                                         'viewed_product_mes_pasado_2':'sum', 
                                         'brand_listing_mes_pasado_2':'sum',
                                         'visited_site_mes_pasado_2':'sum', 
                                         'ad_campaign_hit_mes_pasado_2': 'sum',
                                         'generic_listing_mes_pasado_2' : 'sum',
                                         'searched_products_mes_pasado_2' : 'sum',
                                         'search_engine_hit_mes_pasado_2' : 'sum',
                                         'checkout_mes_pasado_2' : 'sum',
                                         'conversion_mes_pasado_2' : 'sum',
                                         'mes_pasado_2' : 'sum',
                                         'mes_pasado_3' : 'sum',
                                         'semana_pasada_8' : 'sum',
                                         'semana_pasada_9' : 'sum',
                                         'semana_pasada_10' : 'sum',
                                         'semana_pasada_11' : 'sum',
                                         'semana_pasada_12' : 'sum',
                                         'dias_ultimo_evento' : 'min',
                                         'dias_ultima_compra' : 'min',
                                         'Bom_mes_pasado_2' : 'sum',
                                         'Muito_Bom_mes_pasado_2' : 'sum',
                                         'Excelente_mes_pasado_2' : 'sum',
                                         'Samsung_mes_pasado_2' : 'sum',
                                         'iPhone_mes_pasado_2' : 'sum'})

# %%
usuarios_marzo = eventos.loc[eventos["mes"] < 3,:].groupby('person', as_index=False).agg({
                                         'conversion' : 'sum',
                                         'viewed_product_mes_pasado_3':'sum', 
                                         'brand_listing_mes_pasado_3':'sum',
                                         'visited_site_mes_pasado_3':'sum', 
                                         'ad_campaign_hit_mes_pasado_3': 'sum',
                                         'generic_listing_mes_pasado_3' : 'sum',
                                         'searched_products_mes_pasado_3' : 'sum',
                                         'search_engine_hit_mes_pasado_3' : 'sum',
                                         'checkout_mes_pasado_3' : 'sum',
                                         'conversion_mes_pasado_3' : 'sum',
                                         'mes_pasado_3' : 'sum',
                                         'mes_pasado_4' : 'sum',
                                         'semana_pasada_12' : 'sum',
                                         'semana_pasada_13' : 'sum',
                                         'semana_pasada_14' : 'sum',
                                         'semana_pasada_15' : 'sum',
                                         'semana_pasada_16' : 'sum',
                                         'dias_ultimo_evento' : 'min',
                                         'dias_ultima_compra' : 'min',
                                         'Bom_mes_pasado_3' : 'sum',
                                         'Muito_Bom_mes_pasado_3' : 'sum',
                                         'Excelente_mes_pasado_3' : 'sum',
                                         'Samsung_mes_pasado_3' : 'sum',
                                         'iPhone_mes_pasado_3' : 'sum'})

# %%
usuarios_mayo["person"] = usuarios_mayo["person"] + '5'
usuarios_abril["person"] = usuarios_abril["person"] + '4'
usuarios_marzo["person"] = usuarios_marzo["person"] + '3'

# %%
# Obtengo labels para otros meses (MAYO)
compradores_mayo = eventos.loc[(eventos["mes"] == 5) & (eventos["dia"] < 16) & (eventos["conversion"] == True), ["person"]].drop_duplicates()
compradores_mayo["person"] = compradores_mayo["person"] + '5'

# %%
labels_mayo = pd.DataFrame()
labels_mayo["person"] = usuarios_mayo["person"]

# %%
labels_mayo["label"] = (labels_mayo["person"].isin(compradores_mayo["person"]))

# %%
labels_mayo["label"] = labels_mayo["label"].astype(int)

# %%
usuarios_mayo = usuarios_mayo.set_index('person')

# %%
labels_mayo = labels_mayo.set_index('person')

# %%
# Obtengo labels para otros meses (ABRIL)
compradores_abril = eventos.loc[(eventos["mes"] == 4) & (eventos["dia"] < 16) & (eventos["conversion"] == True), ["person"]].drop_duplicates()
compradores_abril["person"] = compradores_abril["person"] + '4'

# %%
labels_abril = pd.DataFrame()
labels_abril["person"] = usuarios_abril["person"]

# %%
labels_abril["label"] = (labels_abril["person"].isin(compradores_abril["person"]))
labels_abril["label"] = labels_abril["label"].astype(int)

# %%
usuarios_abril = usuarios_abril.set_index('person')
labels_abril = labels_abril.set_index('person')

# %%
# Obtengo labels para otros meses (MARZO)
compradores_marzo = eventos.loc[(eventos["mes"] == 3) & (eventos["dia"] < 16) & (eventos["conversion"] == True), ["person"]].drop_duplicates()
compradores_marzo["person"] = compradores_marzo["person"] + '4'

# %%
labels_marzo = pd.DataFrame()
labels_marzo["person"] = usuarios_marzo["person"]

# %%
labels_marzo["label"] = (labels_marzo["person"].isin(compradores_marzo["person"]))
labels_marzo["label"] = labels_marzo["label"].astype(int)

# %%
usuarios_marzo = usuarios_marzo.set_index('person')
labels_marzo = labels_marzo.set_index('person')

# %%
# Incluyo solo los eventos de los usuarios que tengo labels
usuarios_jun_con_labels = usuarios_junio.loc[usuarios_junio['person'].isin(labels_junio['person'])]

# %%
usuarios_jun_con_labels = usuarios_jun_con_labels.set_index('person')

# %%
labels_junio = labels_junio.set_index('person')

# %%
labels = labels_mayo.append(labels_junio)
labels = labels.append(labels_abril)
labels = labels.append(labels_marzo)

# %%
usuarios_mayo = usuarios_mayo.rename(columns={"brand_listing_mes_pasado_1" : "brand_listing_mes_pasado_0",
                                       "mes_pasado_1" : "mes_pasado_0",
                                       "semana_pasada_7" : "semana_pasada_3",
                                       "semana_pasada_4" : "semana_pasada_0",
                                       "search_engine_hit_mes_pasado_1" : "search_engine_hit_mes_pasado_0",
                                       "Bom_mes_pasado_1" : "Bom_mes_pasado_0",
                                       "ad_campaign_hit_mes_pasado_1" : "ad_campaign_hit_mes_pasado_0",
                                       "semana_pasada_6" : "semana_pasada_2",
                                       "mes_pasado_2" : "mes_pasado_1",
                                       "conversion_mes_pasado_1" : "conversion_mes_pasado_0",
                                       "semana_pasada_5" : "semana_pasada_1",
                                       "checkout_mes_pasado_1" : "checkout_mes_pasado_0",
                                       "Excelente_mes_pasado_1" : "Excelente_mes_pasado_0",
                                       "visited_site_mes_pasado_1" : "visited_site_mes_pasado_0",
                                       "semana_pasada_8" : "semana_pasada_4",
                                       "iPhone_mes_pasado_1" : "iPhone_mes_pasado_0",
                                       "Muito_Bom_mes_pasado_1" : "Muito_Bom_mes_pasado_0",
                                       "searched_products_mes_pasado_1" : "searched_products_mes_pasado_0",
                                       "generic_listing_mes_pasado_1" : "generic_listing_mes_pasado_0",
                                       "Samsung_mes_pasado_1" : "Samsung_mes_pasado_0",
                                       "viewed_product_mes_pasado_1" : "viewed_product_mes_pasado_0"})

# %%
usuarios_abril = usuarios_abril.rename(columns={"brand_listing_mes_pasado_2" : "brand_listing_mes_pasado_0",
                                       "mes_pasado_2" : "mes_pasado_0",
                                       "semana_pasada_11" : "semana_pasada_3",
                                       "semana_pasada_8" : "semana_pasada_0",
                                       "search_engine_hit_mes_pasado_2" : "search_engine_hit_mes_pasado_0",
                                       "Bom_mes_pasado_2" : "Bom_mes_pasado_0",
                                       "ad_campaign_hit_mes_pasado_2" : "ad_campaign_hit_mes_pasado_0",
                                       "semana_pasada_10" : "semana_pasada_2",
                                       "mes_pasado_3" : "mes_pasado_1",
                                       "conversion_mes_pasado_2" : "conversion_mes_pasado_0",
                                       "semana_pasada_9" : "semana_pasada_1",
                                       "checkout_mes_pasado_2" : "checkout_mes_pasado_0",
                                       "Excelente_mes_pasado_2" : "Excelente_mes_pasado_0",
                                       "visited_site_mes_pasado_2" : "visited_site_mes_pasado_0",
                                       "semana_pasada_12" : "semana_pasada_4",
                                       "iPhone_mes_pasado_2" : "iPhone_mes_pasado_0",
                                       "Muito_Bom_mes_pasado_2" : "Muito_Bom_mes_pasado_0",
                                       "searched_products_mes_pasado_2" : "searched_products_mes_pasado_0",
                                       "generic_listing_mes_pasado_2" : "generic_listing_mes_pasado_0",
                                       "Samsung_mes_pasado_2" : "Samsung_mes_pasado_0",
                                       "viewed_product_mes_pasado_2" : "viewed_product_mes_pasado_0"})

# %%
usuarios_marzo = usuarios_marzo.rename(columns={"brand_listing_mes_pasado_3" : "brand_listing_mes_pasado_0",
                                       "mes_pasado_3" : "mes_pasado_0",
                                       "semana_pasada_15" : "semana_pasada_3",
                                       "semana_pasada_12" : "semana_pasada_0",
                                       "search_engine_hit_mes_pasado_3" : "search_engine_hit_mes_pasado_0",
                                       "Bom_mes_pasado_3" : "Bom_mes_pasado_0",
                                       "ad_campaign_hit_mes_pasado_3" : "ad_campaign_hit_mes_pasado_0",
                                       "semana_pasada_14" : "semana_pasada_2",
                                       "mes_pasado_4" : "mes_pasado_1",
                                       "conversion_mes_pasado_3" : "conversion_mes_pasado_0",
                                       "semana_pasada_13" : "semana_pasada_1",
                                       "checkout_mes_pasado_3" : "checkout_mes_pasado_0",
                                       "Excelente_mes_pasado_3" : "Excelente_mes_pasado_0",
                                       "visited_site_mes_pasado_3" : "visited_site_mes_pasado_0",
                                       "semana_pasada_16" : "semana_pasada_4",
                                       "iPhone_mes_pasado_3" : "iPhone_mes_pasado_0",
                                       "Muito_Bom_mes_pasado_3" : "Muito_Bom_mes_pasado_0",
                                       "searched_products_mes_pasado_3" : "searched_products_mes_pasado_0",
                                       "generic_listing_mes_pasado_3" : "generic_listing_mes_pasado_0",
                                       "Samsung_mes_pasado_3" : "Samsung_mes_pasado_0",
                                       "viewed_product_mes_pasado_3" : "viewed_product_mes_pasado_0"})

# %%
usuarios_all = usuarios_jun_con_labels.append(usuarios_mayo, sort=False)

# %%
usuarios_all = usuarios_all.append(usuarios_abril, sort=False)

# %%
usuarios_all = usuarios_all.append(usuarios_marzo, sort=False)

# %%
usuarios_all = usuarios_all.join(labels, lsuffix='person', rsuffix='person')

# %%
usuarios_all.sort_values('viewed_product_mes_pasado_0', ascending = False).head(100)
# Out:
#            brand_listing_mes_pasado_0  semana_pasada_4  \
# person
# 6abd2bf1                          5.0            210.0
# 9bf968c53                        23.0            573.0
# 06ed04d64                       218.0            171.0
# 52a4f0b6                         10.0              0.0
# 18489dd5                         43.0              0.0
# 595b9b50                         12.0            272.0
# b1f4dbf64                         5.0              0.0
# 58cb5f05                         14.0              0.0
# 97b0c0d15                       131.0              0.0
# 3787229d                         18.0             58.0
# f8b80f265                        64.0             68.0
# b1f4dbf65                         4.0            346.0
# 333855515                       355.0            311.0
# c8e25442                          5.0            348.0
# f2408126                         16.0              0.0
# 6f19cfd94                        40.0             97.0
# 0d43b999                         25.0             99.0
# c36bf9e55                        74.0             53.0
# 6abd2bf15                         4.0            251.0
# 67bdc9465                        21.0            499.0
# 656c18ef5                        83.0              5.0
# 8fb4929e4                        14.0             20.0
# ddac5f39                         42.0             77.0
# eb6c498c                         17.0            143.0
# f1463a1e                         65.0             13.0
# 53cfdbb6                         59.0              2.0
# bfb74b385                         4.0            133.0
# e1443dd44                       108.0              0.0
# 9b3b43aa4                        36.0             72.0
# 429c8732                         76.0              0.0
# ...                               ...              ...
# 0bcb6925                          4.0              0.0
# 069c5926                         54.0              0.0
# ecd79d0a                          5.0             26.0
# 03a11e22                          2.0              0.0
# 02103564                          9.0              0.0
# 5c744844                         26.0             30.0
# 09ebd1754                        40.0             98.0
# b563761d                          5.0             43.0
# 0765990d                         41.0             39.0
# 14603996                         44.0             51.0
# 7b88de92                         17.0              0.0
# 1775ba854                       539.0            621.0
# cdaa445c5                         4.0            435.0
# c86f17ad3                        36.0            317.0
# f23ad37a                         33.0              9.0
# 10871bbb                         65.0            129.0
# e289012c                        183.0             43.0
# 584f5175                        147.0             13.0
# 4fd0c917                          2.0              0.0
# f8b80f264                       129.0              0.0
# c7cc2c23                          6.0            222.0
# fafdf6094                        37.0            296.0
# ac8f32bc                         19.0              0.0
# 2bc1b6b44                         1.0              0.0
# 910c57465                        24.0              0.0
# b09cbfc25                        58.0             56.0
# 44d76ed6                         11.0              0.0
# 0b9bb6bb                         14.0              0.0
# df3ef64c                         11.0            104.0
# 23aa71b35                         7.0              0.0
#
#            search_engine_hit_mes_pasado_0  ad_campaign_hit_mes_pasado_0  \
# person
# 6abd2bf1                              1.0                           0.0
# 9bf968c53                             6.0                           7.0
# 06ed04d64                             6.0                           2.0
# 52a4f0b6                              3.0                           5.0
# 18489dd5                              5.0                          24.0
# 595b9b50                              7.0                          29.0
# b1f4dbf64                             2.0                           7.0
# 58cb5f05                             11.0                           6.0
# 97b0c0d15                            15.0                          26.0
# 3787229d                             35.0                          20.0
# f8b80f265                             2.0                          19.0
# b1f4dbf65                             0.0                          14.0
# 333855515                            15.0                          13.0
# c8e25442                              6.0                          26.0
# eb6c498c             300.0            111.0  ...                      95.0
# f1463a1e             102.0             89.0  ...                     352.0
# 53cfdbb6             229.0            112.0  ...                     466.0
# bfb74b385            190.0             24.0  ...                     262.0
# e1443dd44              0.0              0.0  ...                     342.0
# 9b3b43aa4            173.0              0.0  ...                     146.0
# 429c8732              26.0              0.0  ...                     132.0
# ...                    ...              ...  ...                       ...
# 0bcb6925             233.0              0.0  ...                     213.0
# 069c5926               8.0            170.0  ...                      97.0
# ecd79d0a             237.0             76.0  ...                     116.0
# 03a11e22               0.0            383.0  ...                     332.0
# 02103564               0.0            219.0  ...                     111.0
# 5c744844               3.0            329.0  ...                     120.0
# 09ebd1754            215.0              0.0  ...                     139.0
# b563761d               0.0             40.0  ...                     250.0
# 0765990d             393.0              0.0  ...                     233.0
# 14603996             137.0             38.0  ...                      79.0
# 7b88de92             395.0              0.0  ...                     101.0
# 1775ba854            380.0              0.0  ...                     176.0
# cdaa445c5            108.0              0.0  ...                     281.0
# c86f17ad3             62.0              0.0  ...                     164.0
# f23ad37a               9.0            387.0  ...                     230.0
# 10871bbb             163.0              3.0  ...                     140.0
# e289012c             398.0            128.0  ...                     144.0
# 584f5175             171.0             17.0  ...                     229.0
# 4fd0c917             191.0            190.0  ...                     108.0
# f8b80f264              0.0              0.0  ...                     165.0
# c7cc2c23              46.0             72.0  ...                      87.0
# fafdf6094            152.0              0.0  ...                     138.0
# ac8f32bc               0.0            173.0  ...                     120.0
# 2bc1b6b44            292.0              0.0  ...                     251.0
# 910c57465            220.0             17.0  ...                     240.0
# b09cbfc25            142.0              8.0  ...                      90.0
# 44d76ed6             179.0             70.0  ...                     121.0
# 0b9bb6bb               0.0             68.0  ...                     150.0
# df3ef64c             118.0             62.0  ...                     247.0
# 23aa71b35             35.0              0.0  ...                     230.0
#
#            visited_site_mes_pasado_0  iPhone_mes_pasado_0  \
# person
# 6abd2bf1                        70.0                983.0
# 9bf968c53                       62.0               1067.0
# 06ed04d64                       45.0                319.0
# 52a4f0b6                        10.0                100.0
# 18489dd5                        48.0                497.0
# 595b9b50                        27.0                 30.0
# b1f4dbf64                       23.0                899.0
# 58cb5f05                        26.0                 78.0
# 97b0c0d15                      103.0                780.0
# 3787229d                        55.0                197.0
# f8b80f265                       32.0                716.0
# b1f4dbf65                       47.0                759.0
# 333855515                       51.0                862.0
# c8e25442                        52.0                497.0
# f2408126                        16.0                352.0
# 6f19cfd94                       38.0                742.0
# 0d43b999                       100.0                 80.0
# c36bf9e55                       62.0                862.0
# 6abd2bf15                       75.0                770.0
# 67bdc9465                      118.0                 79.0
# 656c18ef5                       31.0                803.0
# 8fb4929e4                       13.0                479.0
# ddac5f39                        34.0                217.0
# eb6c498c                        52.0                709.0
# f1463a1e                        26.0                291.0
# 53cfdbb6                        18.0                426.0
# bfb74b385                       18.0                647.0
# e1443dd44                       11.0                235.0
# 9b3b43aa4                       77.0                147.0
# 429c8732                        16.0                 29.0
# ...                              ...                  ...
# 0bcb6925                         8.0                506.0
# 97b0c0d15                  31                        957.0      0
# 3787229d                    0                        952.0      0
# f8b80f265                  34                        925.0      0
# b1f4dbf65                  33                        925.0      0
# 333855515                  31                        917.0      0
# c8e25442                    0                        911.0      0
# f2408126                    0                        879.0      1
# 6f19cfd94                  63                        866.0      0
# 0d43b999                    1                        862.0      0
# c36bf9e55                  31                        862.0      0
# 6abd2bf15                  31                        862.0      0
# 67bdc9465                  31                        855.0      0
# 656c18ef5                  34                        849.0      0
# 8fb4929e4                  63                        848.0      0
# ddac5f39                   16                        830.0      0
# eb6c498c                    1                        822.0      0
# f1463a1e                    2                        785.0      0
# 53cfdbb6                    3                        782.0      0
# bfb74b385                  31                        750.0      0
# e1443dd44                  61                        740.0      0
# 9b3b43aa4                  61                        719.0      0
# 429c8732                    6                        718.0      0
# ...                       ...                          ...    ...
# 0bcb6925                   10                        508.0      0
# 069c5926                    0                        507.0      0
# ecd79d0a                    1                        499.0      1
# 03a11e22                    0                        496.0      0
# 02103564                    0                        495.0      0
# 5c744844                    0                        494.0      0
# 09ebd1754                  65                        493.0      0
# b563761d                    1                        493.0      0
# 0765990d                   15                        490.0      0
# 14603996                    0                        488.0      0
# 7b88de92                    7                        487.0      0
# 1775ba854                  61                        486.0      0
# cdaa445c5                  34                        485.0      0
# c86f17ad3                  97                        484.0      0
# f23ad37a                    0                        483.0      0
# 10871bbb                    3                        482.0      0
# e289012c                    0                        478.0      0
# 584f5175                    0                        477.0      0
# 4fd0c917                    0                        477.0      0
# f8b80f264                  64                        476.0      0
# c7cc2c23                    0                        475.0      1
# fafdf6094                  62                        470.0      0
# ac8f32bc                    1                        470.0      0
# 2bc1b6b44                  61                        470.0      0
# 910c57465                  31                        459.0      0
# b09cbfc25                  31                        457.0      0
# 44d76ed6                    2                        455.0      0
# 0b9bb6bb                    2                        454.0      0
# df3ef64c                    0                        452.0      0
# 23aa71b35                  38                        440.0      0
#
# [100 rows x 25 columns]

# %%
usuarios_all = usuarios_all.loc[usuarios_all['viewed_product_mes_pasado_0'] < 500, :]

# %%
X = usuarios_all.iloc[:,:-1]

# %%
X.head()
# Out:
#           brand_listing_mes_pasado_0  semana_pasada_4  \
# person
# 0008ed71                         0.0              0.0
# 000c79fe                         0.0              0.0
# 001802e4                         0.0              0.0
# 0019e639                       113.0            108.0
# 001b0bf9                         1.0              0.0
#
#           search_engine_hit_mes_pasado_0  ad_campaign_hit_mes_pasado_0  \
# person
# 0008ed71                             0.0                           0.0
# 000c79fe                             1.0                           1.0
# 001802e4                             0.0                           5.0
# 0019e639                             7.0                          16.0
# 001b0bf9                             0.0                           0.0
#
#           mes_pasado_0  Bom_mes_pasado_0  conversion  semana_pasada_2  \
# person
# 0008ed71           6.0               2.0         0.0              6.0
# 000c79fe          17.0               4.0         0.0              0.0
# 001802e4          19.0               3.0         0.0              0.0
# 0019e639         290.0              56.0         2.0            181.0
# 001b0bf9           7.0               0.0         1.0              0.0
#
#           semana_pasada_3  semana_pasada_0             ...               \
# person                                                 ...
# 0008ed71              0.0              0.0             ...
# 000c79fe              0.0             17.0             ...
# 001802e4              0.0             19.0             ...
# 0019e639              0.0              0.0             ...
# 001b0bf9              0.0              0.0             ...
#
#           dias_ultima_compra  Excelente_mes_pasado_0  \
# person
# 0008ed71                 151                     0.0
# 000c79fe                 151                     0.0
# 001802e4                 151                     2.0
# 0019e639                   9                    20.0
# 001b0bf9                   9                     5.0
#
#           visited_site_mes_pasado_0  iPhone_mes_pasado_0  \
# person
# 0008ed71                        2.0                  1.0
# 000c79fe                        1.0                  4.0
# 001802e4                        1.0                  5.0
# 0019e639                       12.0                  0.0
# 001b0bf9                        0.0                  0.0
#
#           Muito_Bom_mes_pasado_0  searched_products_mes_pasado_0  \
# person
# 0008ed71                     1.0                             0.0
# 000c79fe                     0.0                             9.0
# 001802e4                     0.0                             4.0
# 0019e639                    52.0                             1.0
# 001b0bf9                     0.0                             0.0
#
#           generic_listing_mes_pasado_0  Samsung_mes_pasado_0  \
# person
# 0008ed71                           1.0                   1.0
# 000c79fe                           1.0                   0.0
# 001802e4                           4.0                   0.0
# 0019e639                          13.0                  21.0
# 001b0bf9                           1.0                   5.0
#
#           dias_ultimo_evento  viewed_product_mes_pasado_0
# person
# 0008ed71                  14                          0.0
# 000c79fe                   2                          3.0
# 001802e4                   0                          4.0
# 0019e639                   9                        123.0
# 001b0bf9                   9                          2.0
#
# [5 rows x 24 columns]

# %%
Y = usuarios_all.iloc[:,-1]

# %%
Y.head()
# Out:
# person
# 0008ed71    0
# 000c79fe    0
# 001802e4    0
# 0019e639    0
# 001b0bf9    0
# Name: label, dtype: int64

# %%
# FIN DE LA PREPARACION DE LOS DATAFRAMES

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=123)

# %%
# Instancio el regresor
xg_reg = xgb.XGBRegressor(objective ='binary:logistic', 
                colsample_bytree = 0.7, learning_rate = 0.04,
                max_depth = 4, alpha = 0.1, n_estimators = 200,
                seed=1337, min_child_weight = 1, tree_method='exact')

# %%
# Entreno
xg_reg.fit(X_train,y_train)
# Out:
# XGBRegressor(alpha=0.1, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.7, gamma=0, learning_rate=0.04, max_delta_step=0,
#        max_depth=4, min_child_weight=1, missing=None, n_estimators=200,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=1337,
#        silent=True, subsample=1, tree_method='exact')

# %%
# Predecimos
preds = xg_reg.predict(X_test)

# %%
preds
# Out:
# array([0.01986347, 0.03866471, 0.00743072, ..., 0.00170879, 0.01474112,
#        0.10076303], dtype=float32)

# %%
# 0.8532783491119897
import numpy as np
from sklearn import metrics
fpr, tpr, thresholds = metrics.roc_curve(y_test, preds)
metrics.auc(fpr, tpr)
# Out:
# 0.8457985291321034

# %%
np.sqrt(mean_squared_error(y_test, preds))
# Out:
# 0.18165574682854405

# %%
import matplotlib.pyplot as plt

xgb.plot_tree(xg_reg,num_trees=1)
fig = plt.gcf()
fig.set_size_inches(175, 125)
fig.savefig('arbol_xgboost_expandido_marzo.png')

# %%
# Importancia de los features
xgb.plot_importance(xg_reg)
plt.rcParams['figure.figsize'] = [15, 15]
plt.show()

# %%
# Ahora quiero mejorar los hiperparametros
from sklearn.model_selection import *

# %%
xgb_model = xgb.XGBRegressor()

# %%
parameters = {'nthread':[4],
              'objective':['binary:logistic'],
              'learning_rate': [0.05],
              'gamma' : [0],
              'max_depth': [6],
              'min_child_weight': [1],
              'silent': [1],
              'subsample': [1],
              'colsample_bytree': [0.3],
              'n_estimators': [130],
              'seed': [1337],
              'reg_alpha' : [0.01]
             }

# %%
clf = GridSearchCV(xgb_model, parameters, n_jobs=3, 
                   scoring='roc_auc',
                   verbose=2, refit=True)

# %%
clf.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] reg_alpha=0.01, colsample_bytree=0.3, silent=1, learning_rate=0.05, nthread=4, min_child_weight=1, n_estimators=130, subsample=1, seed=1337, objective=binary:logistic, max_depth=6, gamma=0
# [CV] reg_alpha=0.01, colsample_bytree=0.3, silent=1, learning_rate=0.05, nthread=4, min_child_weight=1, n_estimators=130, subsample=1, seed=1337, objective=binary:logistic, max_depth=6, gamma=0
# [CV] reg_alpha=0.01, colsample_bytree=0.3, silent=1, learning_rate=0.05, nthread=4, min_child_weight=1, n_estimators=130, subsample=1, seed=1337, objective=binary:logistic, max_depth=6, gamma=0
# [CV]  reg_alpha=0.01, colsample_bytree=0.3, silent=1, learning_rate=0.05, nthread=4, min_child_weight=1, n_estimators=130, subsample=1, seed=1337, objective=binary:logistic, max_depth=6, gamma=0, total=  16.5s
# [CV]  reg_alpha=0.01, colsample_bytree=0.3, silent=1, learning_rate=0.05, nthread=4, min_child_weight=1, n_estimators=130, subsample=1, seed=1337, objective=binary:logistic, max_depth=6, gamma=0, total=  16.6s
# [CV]  reg_alpha=0.01, colsample_bytree=0.3, silent=1, learning_rate=0.05, nthread=4, min_child_weight=1, n_estimators=130, subsample=1, seed=1337, objective=binary:logistic, max_depth=6, gamma=0, total=  17.0s
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:   18.2s finished
# GridSearchCV(cv=None, error_score='raise',
#        estimator=XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1),
#        fit_params=None, iid=True, n_jobs=3,
#        param_grid={'reg_alpha': [0.01], 'learning_rate': [0.05], 'n_estimators': [130], 'seed': [1337], 'colsample_bytree': [0.3], 'silent': [1], 'nthread': [4], 'min_child_weight': [1], 'subsample': [1], 'objective': ['binary:logistic'], 'max_depth': [6], 'gamma': [0]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='roc_auc', verbose=2)

# %%
best_parameters, score, _ = max(clf.grid_scores_, key=lambda x: x[1])
print('Raw AUC score:', score)
for param_name in sorted(best_parameters.keys()):
    print("%s: %r" % (param_name, best_parameters[param_name]))
# Out:
# ('Raw AUC score:', 0.8462370533965604)
# colsample_bytree: 0.3
# gamma: 0
# learning_rate: 0.05
# max_depth: 6
# min_child_weight: 1
# n_estimators: 130
# nthread: 4
# objective: 'binary:logistic'
# reg_alpha: 0.01
# seed: 1337
# silent: 1
# subsample: 1
# /home/lautaro/anaconda2/lib/python2.7/site-packages/sklearn/model_selection/_search.py:761: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)

# %%
# Ahora tengo que predecir los de prueba de Kaggle
ids_usuarios_kaggle = pd.read_csv('/home/lautaro/Desktop/trocafone_kaggle_test.csv')

# %%
ids_usuarios_kaggle.head()
# Out:
#      person
# 0  4886f805
# 1  0297fc1e
# 2  2d681dd8
# 3  cccea85e
# 4  4c8a8b93

# %%
x_test_kaggle = usuarios_junio.loc[usuarios_junio['person'].isin(ids_usuarios_kaggle['person']), :]

# %%
x_test_kaggle.head()
# Out:
#      person  brand_listing_mes_pasado_0  semana_pasada_4  \
# 1  00091926                        25.0             33.0
# 2  00091a7a                         0.0              0.0
# 3  000ba417                        24.0              0.0
# 5  000e4d9e                        17.0              0.0
# 6  000e619d                        11.0              0.0
#
#    search_engine_hit_mes_pasado_0  ad_campaign_hit_mes_pasado_0  mes_pasado_0  \
# 1                             0.0                          15.0         448.0
# 2                             0.0                           0.0           0.0
# 3                             1.0                           1.0         206.0
# 5                             5.0                          19.0         411.0
# 6                             3.0                           6.0          68.0
#
#    Bom_mes_pasado_0  conversion  semana_pasada_2  semana_pasada_3  \
# 1             102.0         0.0            167.0            132.0
# 2               0.0         0.0              0.0              0.0
# 3             115.0         1.0             68.0              0.0
# 5             124.0         0.0            195.0              0.0
# 6              14.0         0.0             68.0              0.0
#
#               ...               dias_ultima_compra  Excelente_mes_pasado_0  \
# 1             ...                              151                   108.0
# 2             ...                              151                     0.0
# 3             ...                                5                    11.0
# 5             ...                              151                    53.0
# 6             ...                              151                     7.0
#
#    visited_site_mes_pasado_0  iPhone_mes_pasado_0  Muito_Bom_mes_pasado_0  \
# 1                       34.0                253.0                   163.0
# 2                        0.0                  0.0                     0.0
# 3                        6.0                  8.0                    34.0
# 5                       13.0                 21.0                   163.0
# 6                        5.0                  7.0                     8.0
#
#    searched_products_mes_pasado_0  generic_listing_mes_pasado_0  \
# 1                             0.0                           0.0
# 2                             0.0                           0.0
# 3                             0.0                          14.0
# 5                             0.0                          17.0
# 6                             6.0                           8.0
#
#    Samsung_mes_pasado_0  dias_ultimo_evento  viewed_product_mes_pasado_0
# 1                  61.0                   0                        372.0
# 2                   0.0                  66                          0.0
# 3                 110.0                   5                        153.0
# 5                 301.0                   1                        339.0
# 6                  12.0                  13                         28.0
#
# [5 rows x 25 columns]

# %%
x_test_kaggle = x_test_kaggle.set_index('person')

# %%
x_test_kaggle.columns
# Out:
# Index([u'brand_listing_mes_pasado_0', u'semana_pasada_4',
#        u'search_engine_hit_mes_pasado_0', u'ad_campaign_hit_mes_pasado_0',
#        u'mes_pasado_0', u'Bom_mes_pasado_0', u'conversion', u'semana_pasada_2',
#        u'semana_pasada_3', u'semana_pasada_0', u'semana_pasada_1',
#        u'mes_pasado_1', u'conversion_mes_pasado_0', u'checkout_mes_pasado_0',
#        u'dias_ultima_compra', u'Excelente_mes_pasado_0',
#        u'visited_site_mes_pasado_0', u'iPhone_mes_pasado_0',
#        u'Muito_Bom_mes_pasado_0', u'searched_products_mes_pasado_0',
#        u'generic_listing_mes_pasado_0', u'Samsung_mes_pasado_0',
#        u'dias_ultimo_evento', u'viewed_product_mes_pasado_0'],
#       dtype='object')

# %%
# Predecimos
preds_kaggle = xg_reg.predict(x_test_kaggle)

# %%
preds_kaggle
# Out:
# array([0.03489077, 0.0929196 , 0.06830327, ..., 0.13238293, 0.04968993,
#        0.00833027], dtype=float32)

# %%
pd.DataFrame({'person': x_test_kaggle.index, 'label': preds_kaggle}).to_csv('test.csv', index=False, columns=['person', 'label'])
